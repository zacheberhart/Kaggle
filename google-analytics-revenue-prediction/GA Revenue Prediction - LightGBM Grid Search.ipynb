# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import gc
import time
from pandas.core.common import SettingWithCopyWarning
import warnings
import lightgbm as lgb
from sklearn.model_selection import GroupKFold
from copy import deepcopy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# notebook settings
warnings.simplefilter('error', SettingWithCopyWarning)
gc.enable()
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# set path
PATH = '../../data/ga_revenue/'
# Out:
# /anaconda3/lib/python3.6/site-packages/lightgbm/__init__.py:45: FutureWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS will be built by the Apple Clang compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you won't need to install the gcc compiler anymore.
# Instead of that, you'll need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", FutureWarning)

# %% [markdown]
# # LightGBM Grid Search

# %%
def get_folds(df = None, n_splits = 5):
    
    # Get sorted unique visitors
    unique_vis = np.array(sorted(df['fullVisitorId'].unique()))

    # Get folds
    folds = GroupKFold(n_splits=n_splits)
    fold_ids = []
    ids = np.arange(df.shape[0])
    for trn_vis, val_vis in folds.split(X=unique_vis, y=unique_vis, groups=unique_vis):
        fold_ids.append(
            [
                ids[df['fullVisitorId'].isin(unique_vis[trn_vis])],
                ids[df['fullVisitorId'].isin(unique_vis[val_vis])]
            ]
        )

    return fold_ids

# %% [markdown]
# ## Params to Search

# %%
# ordered in which to test first
params_to_search = {
    'n_estimators': [10000, 20000],
    'max_depth': [5, 15, 25],
    'num_leaves': [25, 54, 75],
    'min_child_samples': [20, 36, 50]
}

# %% [markdown]
# ## Load & Process Data

# %%
df = pd.read_feather(PATH+'feathers/main&poly_float32')

train = deepcopy(df[df['dataset'] == 'train'])
test = deepcopy(df[df['dataset'] == 'test'])
del df

# drop dataset identifier and reset index
train.drop('dataset', axis = 1, inplace = True)
test.drop('dataset', axis = 1, inplace = True)
train.reset_index(drop = True, inplace = True)
test.reset_index(drop = True, inplace = True)

y_reg = train['totals.transactionRevenue'].fillna(0)
del train['totals.transactionRevenue']

if 'totals.transactionRevenue' in test.columns:
    del test['totals.transactionRevenue']

# %%
categorical_features = [
    
    'channelGrouping', 'visitNumber', 'device.browser', 'device.deviceCategory',
    'device.isMobile', 'device.operatingSystem', 'geoNetwork.city', 'geoNetwork.continent',
    'geoNetwork.country', 'geoNetwork.metro', 'geoNetwork.networkDomain', 'geoNetwork.region',
    'geoNetwork.subContinent', 'trafficSource.adContent', 'trafficSource.adwordsClickInfo.adNetworkType',
    'trafficSource.adwordsClickInfo.gclId', 'trafficSource.adwordsClickInfo.page', 'trafficSource.adwordsClickInfo.slot',
    'trafficSource.campaign', 'trafficSource.keyword', 'trafficSource.medium', 'trafficSource.referralPath',
    'trafficSource.source', 'visitStartTimeLOCALYear', 'visitStartTimeLOCALMonth', 'visitStartTimeLOCALWeek',
    'visitStartTimeLOCALDay', 'visitStartTimeLOCALDayofweek', 'visitStartTimeLOCALDayofyear', 'visitStartTimeLOCALIs_month_end',
    'visitStartTimeLOCALIs_month_start', 'visitStartTimeLOCALIs_quarter_end', 'visitStartTimeLOCALIs_quarter_start',
    'visitStartTimeLOCALIs_year_end', 'visitStartTimeLOCALIs_year_start', 'visitStartTimeLOCALHourofday',
    'return_visit', 'landing', 'bounce', 'user_has_purchased_before', 'browser_os', 'browser_device', 'os_device',
    'channel_device', 'channel_domain', 'city_country_mismatch', 'is_holiday'
    
]

contin_features = [
    
    'totals.hits', 'totals.pageviews', 'days_after_holiday', 'days_before_holiday', 'holiday_anticipation',
    'holiday_gap', 'days_since_last_visit', 'days_since_first_visit'
    
]

excluded_features = [
    
    'date', 'fullVisitorId', 'sessionId', 'totals.transactionRevenue', 'visitId',
    'visitStartTime', 'visitStartTimeLOCAL', 'visitStartTimeLOCALElapsed'

]

# set remaining cols as continuous
additional_contin_vars = deepcopy([c for c in train.columns
                                   if c not in categorical_features + contin_features + excluded_features
                                  ])

# add the additional engineered cols to continuous
contin_features += additional_contin_vars

# %%
for f in categorical_features:
    train[f], indexer = pd.factorize(train[f])
    if test[f].dtype == bool:
        test[f] = indexer.get_indexer(deepcopy(test[f].astype(int)))
    else:
        test[f] = indexer.get_indexer(test[f])

train_features = [_f for _f in train.columns if _f not in excluded_features]
X_train, y_train = train[train_features], y_reg

# %% [markdown]
# ## Build & Train Model

# %%
n_estimators = 20000

params = {
    
    'num_leaves': 54,
    'max_depth': 15,
    'min_child_samples': 36,
    
    'objective':'regression',
    'metric':'rmse',
    'verbose': 1,
    'learning_rate': 0.01,
    'bagging_fraction': 0.99,
    'feature_fraction': 0.99,
    "random_state":42,
    "bagging_seed" : 42,
    "verbosity" : -1,
    "bagging_frequency" : 5,
    'lambda_l2': 0.5,
    'lambda_l1': 0.5
    
}

# %%
folds = get_folds(df = train, n_splits = 5)

train_features = [_f for _f in train.columns if _f not in excluded_features]

importances = pd.DataFrame()
oof_reg_preds = np.zeros(train.shape[0])
sub_reg_preds = np.zeros(test.shape[0])

for fold_, (trn_, val_) in enumerate(folds):
    
    print("Fold:",fold_)
    trn_x, trn_y = train[train_features].iloc[trn_], y_reg.iloc[trn_]
    val_x, val_y = train[train_features].iloc[val_], y_reg.iloc[val_]
    
    # init & fit
    print('Fitting model...')
    reg = lgb.LGBMRegressor(**params, n_estimators = n_estimators)
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(val_x, np.log1p(val_y))],
        early_stopping_rounds=50,
        verbose=100,
        eval_metric='rmse'
    )
    
    # feature importance
    imp_df = pd.DataFrame()
    imp_df['feature'] = train_features
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_reg_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_reg_preds[oof_reg_preds < 0] = 0
    _preds = reg.predict(test[train_features], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_reg_preds += np.expm1(_preds) / len(folds)
    
mean_squared_error(np.log1p(y_reg), oof_reg_preds) ** .5
# Out:
# Fold: 0
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66083
# [200]	valid_0's rmse: 1.58186
# [300]	valid_0's rmse: 1.56004
# [400]	valid_0's rmse: 1.55223
# [500]	valid_0's rmse: 1.54807
# [600]	valid_0's rmse: 1.54727
# [700]	valid_0's rmse: 1.54521
# [800]	valid_0's rmse: 1.54288
# [900]	valid_0's rmse: 1.54124
# [1000]	valid_0's rmse: 1.54053
# [1100]	valid_0's rmse: 1.53977
# Early stopping, best iteration is:
# [1128]	valid_0's rmse: 1.53963
# Fold: 1
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63556
# [200]	valid_0's rmse: 1.56116
# [300]	valid_0's rmse: 1.54112
# [400]	valid_0's rmse: 1.53308
# [500]	valid_0's rmse: 1.53019
# [600]	valid_0's rmse: 1.52883
# [700]	valid_0's rmse: 1.52746
# [800]	valid_0's rmse: 1.52617
# [900]	valid_0's rmse: 1.52554
# [1000]	valid_0's rmse: 1.52461
# [1100]	valid_0's rmse: 1.52365
# [1200]	valid_0's rmse: 1.52285
# [1300]	valid_0's rmse: 1.52259
# [1400]	valid_0's rmse: 1.5224
# Early stopping, best iteration is:
# [1427]	valid_0's rmse: 1.52233
# Fold: 2
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6464
# [200]	valid_0's rmse: 1.56357
# [300]	valid_0's rmse: 1.53926
# [400]	valid_0's rmse: 1.53052
# [500]	valid_0's rmse: 1.52623
# [600]	valid_0's rmse: 1.52446
# [700]	valid_0's rmse: 1.52258
# [800]	valid_0's rmse: 1.5212
# [900]	valid_0's rmse: 1.52015
# [1000]	valid_0's rmse: 1.5193
# [1100]	valid_0's rmse: 1.51874
# [1200]	valid_0's rmse: 1.51823
# [1300]	valid_0's rmse: 1.51772
# [1400]	valid_0's rmse: 1.51744
# [1500]	valid_0's rmse: 1.51743
# Early stopping, best iteration is:
# [1475]	valid_0's rmse: 1.5173
# Fold: 3
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63215
# [200]	valid_0's rmse: 1.55446
# [300]	valid_0's rmse: 1.53329
# [400]	valid_0's rmse: 1.52506
# [500]	valid_0's rmse: 1.52171
# [600]	valid_0's rmse: 1.52062
# [700]	valid_0's rmse: 1.51914
# [800]	valid_0's rmse: 1.51768
# [900]	valid_0's rmse: 1.51648
# [1000]	valid_0's rmse: 1.51562
# [1100]	valid_0's rmse: 1.51483
# [1200]	valid_0's rmse: 1.51474
# Early stopping, best iteration is:
# [1168]	valid_0's rmse: 1.51455
# Fold: 4
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66359
# [200]	valid_0's rmse: 1.58903
# [300]	valid_0's rmse: 1.56938
# [400]	valid_0's rmse: 1.56084
# [500]	valid_0's rmse: 1.55833
# [600]	valid_0's rmse: 1.5571
# [700]	valid_0's rmse: 1.55648
# [800]	valid_0's rmse: 1.5552
# [900]	valid_0's rmse: 1.55429
# [1000]	valid_0's rmse: 1.55332
# [1100]	valid_0's rmse: 1.55271
# [1200]	valid_0's rmse: 1.55237
# [1300]	valid_0's rmse: 1.55192
# [1400]	valid_0's rmse: 1.55169
# Early stopping, best iteration is:
# [1424]	valid_0's rmse: 1.55163
# 18.40464367718644

# %%
n_estimators = 10000

params = {
    
    'num_leaves': 54,
    'max_depth': 15,
    'min_child_samples': 36,
    
    'objective':'regression',
    'metric':'rmse',
    'verbose': 1,
    'learning_rate': 0.01,
    'bagging_fraction': 0.99,
    'feature_fraction': 0.99,
    "random_state":42,
    "bagging_seed" : 42,
    "verbosity" : -1,
    "bagging_frequency" : 5,
    'lambda_l2': 0.5,
    'lambda_l1': 0.5
    
}

# %%
folds = get_folds(df = train, n_splits = 5)

train_features = [_f for _f in train.columns if _f not in excluded_features]

importances = pd.DataFrame()
oof_reg_preds = np.zeros(train.shape[0])
sub_reg_preds = np.zeros(test.shape[0])

for fold_, (trn_, val_) in enumerate(folds):
    
    print("Fold:",fold_)
    trn_x, trn_y = train[train_features].iloc[trn_], y_reg.iloc[trn_]
    val_x, val_y = train[train_features].iloc[val_], y_reg.iloc[val_]
    
    # init & fit
    print('Fitting model...')
    reg = lgb.LGBMRegressor(**params, n_estimators = n_estimators)
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(val_x, np.log1p(val_y))],
        early_stopping_rounds=50,
        verbose=100,
        eval_metric='rmse'
    )
    
    # feature importance
    imp_df = pd.DataFrame()
    imp_df['feature'] = train_features
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_reg_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_reg_preds[oof_reg_preds < 0] = 0
    _preds = reg.predict(test[train_features], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_reg_preds += np.expm1(_preds) / len(folds)
    
mean_squared_error(np.log1p(y_reg), oof_reg_preds) ** .5
# Out:
# Fold: 0
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66083
# [200]	valid_0's rmse: 1.58186
# [300]	valid_0's rmse: 1.56004
# [400]	valid_0's rmse: 1.55223
# [500]	valid_0's rmse: 1.54807
# [600]	valid_0's rmse: 1.54727
# [700]	valid_0's rmse: 1.54521
# [800]	valid_0's rmse: 1.54288
# [900]	valid_0's rmse: 1.54124
# [1000]	valid_0's rmse: 1.54053
# [1100]	valid_0's rmse: 1.53977
# Early stopping, best iteration is:
# [1128]	valid_0's rmse: 1.53963
# Fold: 1
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63556
# [200]	valid_0's rmse: 1.56116
# [300]	valid_0's rmse: 1.54112
# [400]	valid_0's rmse: 1.53308
# [500]	valid_0's rmse: 1.53019
# [600]	valid_0's rmse: 1.52883
# [700]	valid_0's rmse: 1.52746
# [800]	valid_0's rmse: 1.52617
# [900]	valid_0's rmse: 1.52554
# [1000]	valid_0's rmse: 1.52461
# [1100]	valid_0's rmse: 1.52365
# [1200]	valid_0's rmse: 1.52285
# [1300]	valid_0's rmse: 1.52259
# [1400]	valid_0's rmse: 1.5224
# Early stopping, best iteration is:
# [1427]	valid_0's rmse: 1.52233
# Fold: 2
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6464
# [200]	valid_0's rmse: 1.56357
# [300]	valid_0's rmse: 1.53926
# [400]	valid_0's rmse: 1.53052
# [500]	valid_0's rmse: 1.52623
# [600]	valid_0's rmse: 1.52446
# [700]	valid_0's rmse: 1.52258
# [800]	valid_0's rmse: 1.5212
# [900]	valid_0's rmse: 1.52015
# [1000]	valid_0's rmse: 1.5193
# [1100]	valid_0's rmse: 1.51874
# [1200]	valid_0's rmse: 1.51823
# [1300]	valid_0's rmse: 1.51772
# [1400]	valid_0's rmse: 1.51744
# [1500]	valid_0's rmse: 1.51743
# Early stopping, best iteration is:
# [1475]	valid_0's rmse: 1.5173
# Fold: 3
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63215
# [200]	valid_0's rmse: 1.55446
# [300]	valid_0's rmse: 1.53329
# [400]	valid_0's rmse: 1.52506
# [500]	valid_0's rmse: 1.52171
# [600]	valid_0's rmse: 1.52062
# [700]	valid_0's rmse: 1.51914
# [800]	valid_0's rmse: 1.51768
# [900]	valid_0's rmse: 1.51648
# [1000]	valid_0's rmse: 1.51562
# [1100]	valid_0's rmse: 1.51483
# [1200]	valid_0's rmse: 1.51474
# Early stopping, best iteration is:
# [1168]	valid_0's rmse: 1.51455
# Fold: 4
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66359
# [200]	valid_0's rmse: 1.58903
# [300]	valid_0's rmse: 1.56938
# [400]	valid_0's rmse: 1.56084
# [500]	valid_0's rmse: 1.55833
# [600]	valid_0's rmse: 1.5571
# [700]	valid_0's rmse: 1.55648
# [800]	valid_0's rmse: 1.5552
# [900]	valid_0's rmse: 1.55429
# [1000]	valid_0's rmse: 1.55332
# [1100]	valid_0's rmse: 1.55271
# [1200]	valid_0's rmse: 1.55237
# [1300]	valid_0's rmse: 1.55192
# [1400]	valid_0's rmse: 1.55169
# Early stopping, best iteration is:
# [1424]	valid_0's rmse: 1.55163
# 18.660173492797995

# %%
n_estimators = 10000

params = {
    
    'num_leaves': 54,
    'max_depth': 5,
    'min_child_samples': 36,
    
    'objective':'regression',
    'metric':'rmse',
    'verbose': 1,
    'learning_rate': 0.01,
    'bagging_fraction': 0.99,
    'feature_fraction': 0.99,
    "random_state":42,
    "bagging_seed" : 42,
    "verbosity" : -1,
    "bagging_frequency" : 5,
    'lambda_l2': 0.5,
    'lambda_l1': 0.5
    
}

# %%
folds = get_folds(df = train, n_splits = 5)

train_features = [_f for _f in train.columns if _f not in excluded_features]

importances = pd.DataFrame()
oof_reg_preds = np.zeros(train.shape[0])
sub_reg_preds = np.zeros(test.shape[0])

for fold_, (trn_, val_) in enumerate(folds):
    
    print("Fold:",fold_)
    trn_x, trn_y = train[train_features].iloc[trn_], y_reg.iloc[trn_]
    val_x, val_y = train[train_features].iloc[val_], y_reg.iloc[val_]
    
    # init & fit
    print('Fitting model...')
    reg = lgb.LGBMRegressor(**params, n_estimators = n_estimators)
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(val_x, np.log1p(val_y))],
        early_stopping_rounds=50,
        verbose=100,
        eval_metric='rmse'
    )
    
    # feature importance
    imp_df = pd.DataFrame()
    imp_df['feature'] = train_features
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_reg_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_reg_preds[oof_reg_preds < 0] = 0
    _preds = reg.predict(test[train_features], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_reg_preds += np.expm1(_preds) / len(folds)
    
mean_squared_error(np.log1p(y_reg), oof_reg_preds) ** .5
# Out:
# Fold: 0
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.68121
# [200]	valid_0's rmse: 1.60424
# [300]	valid_0's rmse: 1.58064
# [400]	valid_0's rmse: 1.57074
# [500]	valid_0's rmse: 1.56517
# [600]	valid_0's rmse: 1.5606
# [700]	valid_0's rmse: 1.55693
# [800]	valid_0's rmse: 1.55362
# [900]	valid_0's rmse: 1.55073
# [1000]	valid_0's rmse: 1.54851
# [1100]	valid_0's rmse: 1.54651
# [1200]	valid_0's rmse: 1.54495
# [1300]	valid_0's rmse: 1.54378
# [1400]	valid_0's rmse: 1.54278
# [1500]	valid_0's rmse: 1.54192
# [1600]	valid_0's rmse: 1.54143
# [1700]	valid_0's rmse: 1.54103
# [1800]	valid_0's rmse: 1.54071
# [1900]	valid_0's rmse: 1.54053
# [2000]	valid_0's rmse: 1.54025
# [2100]	valid_0's rmse: 1.54008
# [2200]	valid_0's rmse: 1.54001
# Early stopping, best iteration is:
# [2207]	valid_0's rmse: 1.53997
# Fold: 1
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6563
# [200]	valid_0's rmse: 1.58331
# [300]	valid_0's rmse: 1.56155
# [400]	valid_0's rmse: 1.55205
# [500]	valid_0's rmse: 1.54649
# [600]	valid_0's rmse: 1.54273
# [700]	valid_0's rmse: 1.54052
# [800]	valid_0's rmse: 1.5384
# [900]	valid_0's rmse: 1.53688
# [1000]	valid_0's rmse: 1.53591
# [1100]	valid_0's rmse: 1.53498
# [1200]	valid_0's rmse: 1.53429
# [1300]	valid_0's rmse: 1.53382
# [1400]	valid_0's rmse: 1.53332
# [1500]	valid_0's rmse: 1.53282
# [1600]	valid_0's rmse: 1.53232
# [1700]	valid_0's rmse: 1.5321
# [1800]	valid_0's rmse: 1.53184
# Early stopping, best iteration is:
# [1812]	valid_0's rmse: 1.53174
# Fold: 2
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66979
# [200]	valid_0's rmse: 1.58986
# [300]	valid_0's rmse: 1.56494
# [400]	valid_0's rmse: 1.55307
# [500]	valid_0's rmse: 1.54744
# [600]	valid_0's rmse: 1.54265
# [700]	valid_0's rmse: 1.53943
# [800]	valid_0's rmse: 1.5371
# [900]	valid_0's rmse: 1.53536
# [1000]	valid_0's rmse: 1.53362
# [1100]	valid_0's rmse: 1.53233
# [1200]	valid_0's rmse: 1.53086
# [1300]	valid_0's rmse: 1.52948
# [1400]	valid_0's rmse: 1.5282
# [1500]	valid_0's rmse: 1.52751
# [1600]	valid_0's rmse: 1.52713
# Early stopping, best iteration is:
# [1637]	valid_0's rmse: 1.52698
# Fold: 3
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.65457
# [200]	valid_0's rmse: 1.57991
# [300]	valid_0's rmse: 1.55797
# [400]	valid_0's rmse: 1.54816
# [500]	valid_0's rmse: 1.54178
# [600]	valid_0's rmse: 1.53765
# [700]	valid_0's rmse: 1.53429
# [800]	valid_0's rmse: 1.53157
# [900]	valid_0's rmse: 1.52943
# [1000]	valid_0's rmse: 1.52764
# [1100]	valid_0's rmse: 1.52624
# [1200]	valid_0's rmse: 1.52517
# [1300]	valid_0's rmse: 1.52413
# [1400]	valid_0's rmse: 1.52317
# [1500]	valid_0's rmse: 1.52284
# [1600]	valid_0's rmse: 1.52236
# [1700]	valid_0's rmse: 1.52192
# [1800]	valid_0's rmse: 1.5214
# [1900]	valid_0's rmse: 1.52111
# [2000]	valid_0's rmse: 1.52088
# [2100]	valid_0's rmse: 1.52047
# Early stopping, best iteration is:
# [2120]	valid_0's rmse: 1.52035
# Fold: 4
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.68632
# [200]	valid_0's rmse: 1.61419
# [300]	valid_0's rmse: 1.59457
# [400]	valid_0's rmse: 1.58522
# [500]	valid_0's rmse: 1.5802
# [600]	valid_0's rmse: 1.57508
# [700]	valid_0's rmse: 1.57127
# [800]	valid_0's rmse: 1.56817
# [900]	valid_0's rmse: 1.56567
# [1000]	valid_0's rmse: 1.56379
# [1100]	valid_0's rmse: 1.56263
# [1200]	valid_0's rmse: 1.56154
# [1300]	valid_0's rmse: 1.56064
# [1400]	valid_0's rmse: 1.55976
# [1500]	valid_0's rmse: 1.55892
# [1600]	valid_0's rmse: 1.55853
# [1700]	valid_0's rmse: 1.55813
# [1800]	valid_0's rmse: 1.55766
# [1900]	valid_0's rmse: 1.55725
# [2000]	valid_0's rmse: 1.55686
# [2100]	valid_0's rmse: 1.55667
# [2200]	valid_0's rmse: 1.55649
# [2300]	valid_0's rmse: 1.55633
# [2400]	valid_0's rmse: 1.55613
# Early stopping, best iteration is:
# [2416]	valid_0's rmse: 1.55603
# 18.5522348439846

# %%
n_estimators = 10000

params = {
    
    'num_leaves': 54,
    'max_depth': 25,
    'min_child_samples': 36,
    
    'objective':'regression',
    'metric':'rmse',
    'verbose': 1,
    'learning_rate': 0.01,
    'bagging_fraction': 0.99,
    'feature_fraction': 0.99,
    "random_state":42,
    "bagging_seed" : 42,
    "verbosity" : -1,
    "bagging_frequency" : 5,
    'lambda_l2': 0.5,
    'lambda_l1': 0.5
    
}

# %%
folds = get_folds(df = train, n_splits = 5)

train_features = [_f for _f in train.columns if _f not in excluded_features]

importances = pd.DataFrame()
oof_reg_preds = np.zeros(train.shape[0])
sub_reg_preds = np.zeros(test.shape[0])

for fold_, (trn_, val_) in enumerate(folds):
    
    print("Fold:",fold_)
    trn_x, trn_y = train[train_features].iloc[trn_], y_reg.iloc[trn_]
    val_x, val_y = train[train_features].iloc[val_], y_reg.iloc[val_]
    
    # init & fit
    print('Fitting model...')
    reg = lgb.LGBMRegressor(**params, n_estimators = n_estimators)
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(val_x, np.log1p(val_y))],
        early_stopping_rounds=50,
        verbose=100,
        eval_metric='rmse'
    )
    
    # feature importance
    imp_df = pd.DataFrame()
    imp_df['feature'] = train_features
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_reg_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_reg_preds[oof_reg_preds < 0] = 0
    _preds = reg.predict(test[train_features], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_reg_preds += np.expm1(_preds) / len(folds)
    
mean_squared_error(np.log1p(y_reg), oof_reg_preds) ** .5
# Out:
# Fold: 0
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66083
# [200]	valid_0's rmse: 1.58207
# [300]	valid_0's rmse: 1.55992
# [400]	valid_0's rmse: 1.55176
# [500]	valid_0's rmse: 1.54764
# [600]	valid_0's rmse: 1.54626
# [700]	valid_0's rmse: 1.5444
# [800]	valid_0's rmse: 1.54226
# [900]	valid_0's rmse: 1.54049
# [1000]	valid_0's rmse: 1.53918
# [1100]	valid_0's rmse: 1.53829
# [1200]	valid_0's rmse: 1.53776
# [1300]	valid_0's rmse: 1.53695
# [1400]	valid_0's rmse: 1.53653
# [1500]	valid_0's rmse: 1.5359
# [1600]	valid_0's rmse: 1.53575
# [1700]	valid_0's rmse: 1.53525
# Early stopping, best iteration is:
# [1678]	valid_0's rmse: 1.53524
# Fold: 1
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63556
# [200]	valid_0's rmse: 1.56102
# [300]	valid_0's rmse: 1.54142
# [400]	valid_0's rmse: 1.53387
# [500]	valid_0's rmse: 1.53056
# [600]	valid_0's rmse: 1.52934
# [700]	valid_0's rmse: 1.52841
# [800]	valid_0's rmse: 1.5271
# [900]	valid_0's rmse: 1.52591
# [1000]	valid_0's rmse: 1.52449
# [1100]	valid_0's rmse: 1.52344
# [1200]	valid_0's rmse: 1.52287
# Early stopping, best iteration is:
# [1193]	valid_0's rmse: 1.52283
# Fold: 2
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6464
# [200]	valid_0's rmse: 1.56374
# [300]	valid_0's rmse: 1.53949
# [400]	valid_0's rmse: 1.53111
# [500]	valid_0's rmse: 1.52641
# [600]	valid_0's rmse: 1.525
# [700]	valid_0's rmse: 1.52354
# [800]	valid_0's rmse: 1.52185
# [900]	valid_0's rmse: 1.52128
# [1000]	valid_0's rmse: 1.52074
# [1100]	valid_0's rmse: 1.51982
# [1200]	valid_0's rmse: 1.51939
# [1300]	valid_0's rmse: 1.51887
# Early stopping, best iteration is:
# [1303]	valid_0's rmse: 1.51882
# Fold: 3
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63215
# [200]	valid_0's rmse: 1.55451
# [300]	valid_0's rmse: 1.53378
# [400]	valid_0's rmse: 1.52546
# [500]	valid_0's rmse: 1.5231
# [600]	valid_0's rmse: 1.52185
# [700]	valid_0's rmse: 1.52092
# [800]	valid_0's rmse: 1.51937
# [900]	valid_0's rmse: 1.5179
# [1000]	valid_0's rmse: 1.51769
# [1100]	valid_0's rmse: 1.51714
# [1200]	valid_0's rmse: 1.51678
# [1300]	valid_0's rmse: 1.51618
# [1400]	valid_0's rmse: 1.51579
# [1500]	valid_0's rmse: 1.51578
# Early stopping, best iteration is:
# [1478]	valid_0's rmse: 1.51569
# Fold: 4
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66359
# [200]	valid_0's rmse: 1.58934
# [300]	valid_0's rmse: 1.56948
# [400]	valid_0's rmse: 1.5614
# [500]	valid_0's rmse: 1.55879
# [600]	valid_0's rmse: 1.55744
# [700]	valid_0's rmse: 1.55642
# [800]	valid_0's rmse: 1.55466
# [900]	valid_0's rmse: 1.55372
# [1000]	valid_0's rmse: 1.55294
# Early stopping, best iteration is:
# [1046]	valid_0's rmse: 1.55264
# 18.66783627573961

# %%
n_estimators = 20000

params = {
    
    'num_leaves': 54,
    'max_depth': 5,
    'min_child_samples': 36,
    
    'objective':'regression',
    'metric':'rmse',
    'verbose': 1,
    'learning_rate': 0.01,
    'bagging_fraction': 0.99,
    'feature_fraction': 0.99,
    "random_state":42,
    "bagging_seed" : 42,
    "verbosity" : -1,
    "bagging_frequency" : 5,
    'lambda_l2': 0.5,
    'lambda_l1': 0.5
    
}

# %%
folds = get_folds(df = train, n_splits = 5)

train_features = [_f for _f in train.columns if _f not in excluded_features]

importances = pd.DataFrame()
oof_reg_preds = np.zeros(train.shape[0])
sub_reg_preds = np.zeros(test.shape[0])

for fold_, (trn_, val_) in enumerate(folds):
    
    print("Fold:",fold_)
    trn_x, trn_y = train[train_features].iloc[trn_], y_reg.iloc[trn_]
    val_x, val_y = train[train_features].iloc[val_], y_reg.iloc[val_]
    
    # init & fit
    print('Fitting model...')
    reg = lgb.LGBMRegressor(**params, n_estimators = n_estimators)
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(val_x, np.log1p(val_y))],
        early_stopping_rounds=50,
        verbose=100,
        eval_metric='rmse'
    )
    
    # feature importance
    imp_df = pd.DataFrame()
    imp_df['feature'] = train_features
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_reg_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_reg_preds[oof_reg_preds < 0] = 0
    _preds = reg.predict(test[train_features], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_reg_preds += np.expm1(_preds) / len(folds)
    
mean_squared_error(np.log1p(y_reg), oof_reg_preds) ** .5
# Out:
# Fold: 0
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.68121
# [200]	valid_0's rmse: 1.60424
# [300]	valid_0's rmse: 1.58064
# [400]	valid_0's rmse: 1.57074
# [500]	valid_0's rmse: 1.56517
# [600]	valid_0's rmse: 1.5606
# [700]	valid_0's rmse: 1.55693
# [800]	valid_0's rmse: 1.55362
# [900]	valid_0's rmse: 1.55073
# [1000]	valid_0's rmse: 1.54851
# [1100]	valid_0's rmse: 1.54651
# [1200]	valid_0's rmse: 1.54495
# [1300]	valid_0's rmse: 1.54378
# [1400]	valid_0's rmse: 1.54278
# [1500]	valid_0's rmse: 1.54192
# [1600]	valid_0's rmse: 1.54143
# [1700]	valid_0's rmse: 1.54103
# [1800]	valid_0's rmse: 1.54071
# [1900]	valid_0's rmse: 1.54053
# [2000]	valid_0's rmse: 1.54025
# [2100]	valid_0's rmse: 1.54008
# [2200]	valid_0's rmse: 1.54001
# Early stopping, best iteration is:
# [2207]	valid_0's rmse: 1.53997
# Fold: 1
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6563
# [200]	valid_0's rmse: 1.58331
# [300]	valid_0's rmse: 1.56155
# [400]	valid_0's rmse: 1.55205
# [500]	valid_0's rmse: 1.54649
# [600]	valid_0's rmse: 1.54273
# [700]	valid_0's rmse: 1.54052
# [800]	valid_0's rmse: 1.5384
# [900]	valid_0's rmse: 1.53688
# [1000]	valid_0's rmse: 1.53591
# [1100]	valid_0's rmse: 1.53498
# [1200]	valid_0's rmse: 1.53429
# [1300]	valid_0's rmse: 1.53382
# [1400]	valid_0's rmse: 1.53332
# [1500]	valid_0's rmse: 1.53282
# [1600]	valid_0's rmse: 1.53232
# [1700]	valid_0's rmse: 1.5321
# [1800]	valid_0's rmse: 1.53184
# Early stopping, best iteration is:
# [1812]	valid_0's rmse: 1.53174
# Fold: 2
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66979
# [200]	valid_0's rmse: 1.58986
# [300]	valid_0's rmse: 1.56494
# [400]	valid_0's rmse: 1.55307
# [500]	valid_0's rmse: 1.54744
# [600]	valid_0's rmse: 1.54265
# [700]	valid_0's rmse: 1.53943
# [800]	valid_0's rmse: 1.5371
# [900]	valid_0's rmse: 1.53536
# [1000]	valid_0's rmse: 1.53362
# [1100]	valid_0's rmse: 1.53233
# [1200]	valid_0's rmse: 1.53086
# [1300]	valid_0's rmse: 1.52948
# [1400]	valid_0's rmse: 1.5282
# [1500]	valid_0's rmse: 1.52751
# [1600]	valid_0's rmse: 1.52713
# Early stopping, best iteration is:
# [1637]	valid_0's rmse: 1.52698
# Fold: 3
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.65457
# [200]	valid_0's rmse: 1.57991
# [300]	valid_0's rmse: 1.55797
# [400]	valid_0's rmse: 1.54816
# [500]	valid_0's rmse: 1.54178
# [600]	valid_0's rmse: 1.53765
# [700]	valid_0's rmse: 1.53429
# [800]	valid_0's rmse: 1.53157
# [900]	valid_0's rmse: 1.52943
# [1000]	valid_0's rmse: 1.52764
# [1100]	valid_0's rmse: 1.52624
# [1200]	valid_0's rmse: 1.52517
# [1300]	valid_0's rmse: 1.52413
# [1400]	valid_0's rmse: 1.52317
# [1500]	valid_0's rmse: 1.52284
# [1600]	valid_0's rmse: 1.52236
# [1700]	valid_0's rmse: 1.52192
# [1800]	valid_0's rmse: 1.5214
# [1900]	valid_0's rmse: 1.52111
# [2000]	valid_0's rmse: 1.52088
# [2100]	valid_0's rmse: 1.52047
# Early stopping, best iteration is:
# [2120]	valid_0's rmse: 1.52035
# Fold: 4
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.68632
# [200]	valid_0's rmse: 1.61419
# [300]	valid_0's rmse: 1.59457
# [400]	valid_0's rmse: 1.58522
# [500]	valid_0's rmse: 1.5802
# [600]	valid_0's rmse: 1.57508
# [700]	valid_0's rmse: 1.57127
# [800]	valid_0's rmse: 1.56817
# [900]	valid_0's rmse: 1.56567
# [1000]	valid_0's rmse: 1.56379
# [1100]	valid_0's rmse: 1.56263
# [1200]	valid_0's rmse: 1.56154
# [1300]	valid_0's rmse: 1.56064
# [1400]	valid_0's rmse: 1.55976
# [1500]	valid_0's rmse: 1.55892
# [1600]	valid_0's rmse: 1.55853
# [1700]	valid_0's rmse: 1.55813
# [1800]	valid_0's rmse: 1.55766
# [1900]	valid_0's rmse: 1.55725
# [2000]	valid_0's rmse: 1.55686
# [2100]	valid_0's rmse: 1.55667
# [2200]	valid_0's rmse: 1.55649
# [2300]	valid_0's rmse: 1.55633
# [2400]	valid_0's rmse: 1.55613
# Early stopping, best iteration is:
# [2416]	valid_0's rmse: 1.55603
# 18.504558851058256

# %%
n_estimators = 20000

params = {
    
    'num_leaves': 54,
    'max_depth': 25,
    'min_child_samples': 36,
    
    'objective':'regression',
    'metric':'rmse',
    'verbose': 1,
    'learning_rate': 0.01,
    'bagging_fraction': 0.99,
    'feature_fraction': 0.99,
    "random_state":42,
    "bagging_seed" : 42,
    "verbosity" : -1,
    "bagging_frequency" : 5,
    'lambda_l2': 0.5,
    'lambda_l1': 0.5
    
}

# %%
folds = get_folds(df = train, n_splits = 5)

train_features = [_f for _f in train.columns if _f not in excluded_features]

importances = pd.DataFrame()
oof_reg_preds = np.zeros(train.shape[0])
sub_reg_preds = np.zeros(test.shape[0])

for fold_, (trn_, val_) in enumerate(folds):
    
    print("Fold:",fold_)
    trn_x, trn_y = train[train_features].iloc[trn_], y_reg.iloc[trn_]
    val_x, val_y = train[train_features].iloc[val_], y_reg.iloc[val_]
    
    # init & fit
    print('Fitting model...')
    reg = lgb.LGBMRegressor(**params, n_estimators = n_estimators)
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(val_x, np.log1p(val_y))],
        early_stopping_rounds=50,
        verbose=100,
        eval_metric='rmse'
    )
    
    # feature importance
    imp_df = pd.DataFrame()
    imp_df['feature'] = train_features
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_reg_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_reg_preds[oof_reg_preds < 0] = 0
    _preds = reg.predict(test[train_features], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_reg_preds += np.expm1(_preds) / len(folds)
    
mean_squared_error(np.log1p(y_reg), oof_reg_preds) ** .5
# Out:
# Fold: 0
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66083
# [200]	valid_0's rmse: 1.58207
# [300]	valid_0's rmse: 1.55992
# [400]	valid_0's rmse: 1.55176
# [500]	valid_0's rmse: 1.54764
# [600]	valid_0's rmse: 1.54626
# [700]	valid_0's rmse: 1.5444
# [800]	valid_0's rmse: 1.54226
# [900]	valid_0's rmse: 1.54049
# [1000]	valid_0's rmse: 1.53918
# [1100]	valid_0's rmse: 1.53829
# [1200]	valid_0's rmse: 1.53776
# [1300]	valid_0's rmse: 1.53695
# [1400]	valid_0's rmse: 1.53653
# [1500]	valid_0's rmse: 1.5359
# [1600]	valid_0's rmse: 1.53575
# [1700]	valid_0's rmse: 1.53525
# Early stopping, best iteration is:
# [1678]	valid_0's rmse: 1.53524
# Fold: 1
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63556
# [200]	valid_0's rmse: 1.56102
# [300]	valid_0's rmse: 1.54142
# [400]	valid_0's rmse: 1.53387
# [500]	valid_0's rmse: 1.53056
# [600]	valid_0's rmse: 1.52934
# [700]	valid_0's rmse: 1.52841
# [800]	valid_0's rmse: 1.5271
# [900]	valid_0's rmse: 1.52591
# [1000]	valid_0's rmse: 1.52449
# [1100]	valid_0's rmse: 1.52344
# [1200]	valid_0's rmse: 1.52287
# Early stopping, best iteration is:
# [1193]	valid_0's rmse: 1.52283
# Fold: 2
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6464
# [200]	valid_0's rmse: 1.56374
# [300]	valid_0's rmse: 1.53949
# [400]	valid_0's rmse: 1.53111
# [500]	valid_0's rmse: 1.52641
# [600]	valid_0's rmse: 1.525
# [700]	valid_0's rmse: 1.52354
# [800]	valid_0's rmse: 1.52185
# [900]	valid_0's rmse: 1.52128
# [1000]	valid_0's rmse: 1.52074
# [1100]	valid_0's rmse: 1.51982
# [1200]	valid_0's rmse: 1.51939
# [1300]	valid_0's rmse: 1.51887
# Early stopping, best iteration is:
# [1303]	valid_0's rmse: 1.51882
# Fold: 3
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63215
# [200]	valid_0's rmse: 1.55451
# [300]	valid_0's rmse: 1.53378
# [400]	valid_0's rmse: 1.52546
# [500]	valid_0's rmse: 1.5231
# [600]	valid_0's rmse: 1.52185
# [700]	valid_0's rmse: 1.52092
# [800]	valid_0's rmse: 1.51937
# [900]	valid_0's rmse: 1.5179
# [1000]	valid_0's rmse: 1.51769
# [1100]	valid_0's rmse: 1.51714
# [1200]	valid_0's rmse: 1.51678
# [1300]	valid_0's rmse: 1.51618
# [1400]	valid_0's rmse: 1.51579
# [1500]	valid_0's rmse: 1.51578
# Early stopping, best iteration is:
# [1478]	valid_0's rmse: 1.51569
# Fold: 4
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66359
# [200]	valid_0's rmse: 1.58934
# [300]	valid_0's rmse: 1.56948
# [400]	valid_0's rmse: 1.5614
# [500]	valid_0's rmse: 1.55879
# [600]	valid_0's rmse: 1.55744
# [700]	valid_0's rmse: 1.55642
# [800]	valid_0's rmse: 1.55466
# [900]	valid_0's rmse: 1.55372
# [1000]	valid_0's rmse: 1.55294
# Early stopping, best iteration is:
# [1046]	valid_0's rmse: 1.55264
# 18.66783627573961

# %%
gs = {
    '20000est_15md_54nl': [1.53963, 1.52233, 1.5173, 1.51455, 1.55163],
    '10000est_15md_54nl': [1.53963, 1.52233, 1.5173, 1.51455, 1.55163],
    '10000est_5md_54nl': [1.53997, 1.53174, 1.52698, 1.52035, 1.55603],
    '10000est_25md_54nl': [1.53524, 1.52283, 1.51882, 1.51569, 1.55264],
    '20000est_5md_54nl': [1.53997, 1.53174, 1.52698, 1.52035, 1.55603],
    '20000est_25md_54nl': [1.53524, 1.52283, 1.51882, 1.51569, 1.55264],
}

# %%
for k, v in gs.items(): print('{}:'.format(k), np.array(v).mean())
# Out:
# 20000est_15md: 1.529088
# 10000est_15md: 1.529088
# 10000est_5md: 1.5350139999999999
# 10000est_25md: 1.529044
# 20000est_5md: 1.5350139999999999
# 20000est_25md: 1.529044

# %%
# ordered in which to test first
params_to_search = {
    'num_leaves': [25, 54, 75],
    'min_child_samples': [20, 36, 50]
}

# %%
n_estimators = 10000

params = {
    
    'num_leaves': 25,
    'max_depth': 25,
    'min_child_samples': 36,
    
    'objective':'regression',
    'metric':'rmse',
    'verbose': 1,
    'learning_rate': 0.01,
    'bagging_fraction': 0.99,
    'feature_fraction': 0.99,
    "random_state":42,
    "bagging_seed" : 42,
    "verbosity" : -1,
    "bagging_frequency" : 5,
    'lambda_l2': 0.5,
    'lambda_l1': 0.5
    
}

folds = get_folds(df = train, n_splits = 5)

train_features = [_f for _f in train.columns if _f not in excluded_features]

importances = pd.DataFrame()
oof_reg_preds = np.zeros(train.shape[0])
sub_reg_preds = np.zeros(test.shape[0])

for fold_, (trn_, val_) in enumerate(folds):
    
    print("Fold:",fold_)
    trn_x, trn_y = train[train_features].iloc[trn_], y_reg.iloc[trn_]
    val_x, val_y = train[train_features].iloc[val_], y_reg.iloc[val_]
    
    # init & fit
    print('Fitting model...')
    reg = lgb.LGBMRegressor(**params, n_estimators = n_estimators)
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(val_x, np.log1p(val_y))],
        early_stopping_rounds=50,
        verbose=100,
        eval_metric='rmse'
    )
    
    # feature importance
    imp_df = pd.DataFrame()
    imp_df['feature'] = train_features
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_reg_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_reg_preds[oof_reg_preds < 0] = 0
    _preds = reg.predict(test[train_features], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_reg_preds += np.expm1(_preds) / len(folds)
    
mean_squared_error(np.log1p(y_reg), oof_reg_preds) ** .5
# Out:
# Fold: 0
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6768
# [200]	valid_0's rmse: 1.5969
# [300]	valid_0's rmse: 1.57293
# [400]	valid_0's rmse: 1.56427
# [500]	valid_0's rmse: 1.55988
# [600]	valid_0's rmse: 1.55738
# [700]	valid_0's rmse: 1.55557
# [800]	valid_0's rmse: 1.5519
# [900]	valid_0's rmse: 1.54956
# [1000]	valid_0's rmse: 1.5475
# [1100]	valid_0's rmse: 1.54582
# [1200]	valid_0's rmse: 1.54425
# [1300]	valid_0's rmse: 1.54273
# [1400]	valid_0's rmse: 1.5418
# [1500]	valid_0's rmse: 1.54139
# [1600]	valid_0's rmse: 1.54096
# [1700]	valid_0's rmse: 1.54059
# [1800]	valid_0's rmse: 1.54021
# [1900]	valid_0's rmse: 1.53983
# [2000]	valid_0's rmse: 1.53957
# [2100]	valid_0's rmse: 1.53949
# Early stopping, best iteration is:
# [2071]	valid_0's rmse: 1.53939
# Fold: 1
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.65062
# [200]	valid_0's rmse: 1.57602
# [300]	valid_0's rmse: 1.55357
# [400]	valid_0's rmse: 1.54532
# [500]	valid_0's rmse: 1.54163
# [600]	valid_0's rmse: 1.53934
# [700]	valid_0's rmse: 1.53797
# [800]	valid_0's rmse: 1.53637
# [900]	valid_0's rmse: 1.53428
# [1000]	valid_0's rmse: 1.53243
# [1100]	valid_0's rmse: 1.5314
# [1200]	valid_0's rmse: 1.53018
# [1300]	valid_0's rmse: 1.52808
# [1400]	valid_0's rmse: 1.52753
# [1500]	valid_0's rmse: 1.52726
# [1600]	valid_0's rmse: 1.52673
# [1700]	valid_0's rmse: 1.52613
# [1800]	valid_0's rmse: 1.52576
# [1900]	valid_0's rmse: 1.5253
# Early stopping, best iteration is:
# [1922]	valid_0's rmse: 1.52524
# Fold: 2
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66396
# [200]	valid_0's rmse: 1.58062
# [300]	valid_0's rmse: 1.55423
# [400]	valid_0's rmse: 1.54378
# [500]	valid_0's rmse: 1.53918
# [600]	valid_0's rmse: 1.53652
# [700]	valid_0's rmse: 1.53433
# [800]	valid_0's rmse: 1.53233
# [900]	valid_0's rmse: 1.5309
# [1000]	valid_0's rmse: 1.52954
# [1100]	valid_0's rmse: 1.52767
# [1200]	valid_0's rmse: 1.52568
# [1300]	valid_0's rmse: 1.52467
# [1400]	valid_0's rmse: 1.52369
# [1500]	valid_0's rmse: 1.5229
# [1600]	valid_0's rmse: 1.52254
# [1700]	valid_0's rmse: 1.52168
# [1800]	valid_0's rmse: 1.52121
# Early stopping, best iteration is:
# [1846]	valid_0's rmse: 1.52115
# Fold: 3
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.64796
# [200]	valid_0's rmse: 1.56909
# [300]	valid_0's rmse: 1.54597
# [400]	valid_0's rmse: 1.53678
# [500]	valid_0's rmse: 1.53303
# [600]	valid_0's rmse: 1.53078
# [700]	valid_0's rmse: 1.52921
# [800]	valid_0's rmse: 1.52679
# [900]	valid_0's rmse: 1.52492
# [1000]	valid_0's rmse: 1.52342
# [1100]	valid_0's rmse: 1.5226
# [1200]	valid_0's rmse: 1.52141
# [1300]	valid_0's rmse: 1.52094
# [1400]	valid_0's rmse: 1.51968
# [1500]	valid_0's rmse: 1.51898
# [1600]	valid_0's rmse: 1.51838
# [1700]	valid_0's rmse: 1.51798
# [1800]	valid_0's rmse: 1.51763
# [1900]	valid_0's rmse: 1.5171
# [2000]	valid_0's rmse: 1.51678
# [2100]	valid_0's rmse: 1.51628
# [2200]	valid_0's rmse: 1.51607
# Early stopping, best iteration is:
# [2187]	valid_0's rmse: 1.51599
# Fold: 4
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.68088
# [200]	valid_0's rmse: 1.60578
# [300]	valid_0's rmse: 1.58405
# [400]	valid_0's rmse: 1.57514
# [500]	valid_0's rmse: 1.57107
# [600]	valid_0's rmse: 1.56839
# [700]	valid_0's rmse: 1.56621
# [800]	valid_0's rmse: 1.56403
# [900]	valid_0's rmse: 1.56119
# [1000]	valid_0's rmse: 1.55955
# [1100]	valid_0's rmse: 1.55784
# [1200]	valid_0's rmse: 1.55659
# [1300]	valid_0's rmse: 1.5562
# [1400]	valid_0's rmse: 1.55588
# [1500]	valid_0's rmse: 1.55537
# [1600]	valid_0's rmse: 1.55458
# [1700]	valid_0's rmse: 1.55414
# [1800]	valid_0's rmse: 1.55383
# Early stopping, best iteration is:
# [1815]	valid_0's rmse: 1.55375
# 18.613512748322357

# %%
n_estimators = 10000

params = {
    
    'num_leaves': 75,
    'max_depth': 25,
    'min_child_samples': 36,
    
    'objective':'regression',
    'metric':'rmse',
    'verbose': 1,
    'learning_rate': 0.01,
    'bagging_fraction': 0.99,
    'feature_fraction': 0.99,
    "random_state":42,
    "bagging_seed" : 42,
    "verbosity" : -1,
    "bagging_frequency" : 5,
    'lambda_l2': 0.5,
    'lambda_l1': 0.5
    
}

folds = get_folds(df = train, n_splits = 5)

train_features = [_f for _f in train.columns if _f not in excluded_features]

importances = pd.DataFrame()
oof_reg_preds = np.zeros(train.shape[0])
sub_reg_preds = np.zeros(test.shape[0])

for fold_, (trn_, val_) in enumerate(folds):
    
    print("Fold:",fold_)
    trn_x, trn_y = train[train_features].iloc[trn_], y_reg.iloc[trn_]
    val_x, val_y = train[train_features].iloc[val_], y_reg.iloc[val_]
    
    # init & fit
    print('Fitting model...')
    reg = lgb.LGBMRegressor(**params, n_estimators = n_estimators)
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(val_x, np.log1p(val_y))],
        early_stopping_rounds=50,
        verbose=100,
        eval_metric='rmse'
    )
    
    # feature importance
    imp_df = pd.DataFrame()
    imp_df['feature'] = train_features
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_reg_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_reg_preds[oof_reg_preds < 0] = 0
    _preds = reg.predict(test[train_features], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_reg_preds += np.expm1(_preds) / len(folds)
    
mean_squared_error(np.log1p(y_reg), oof_reg_preds) ** .5
# Out:
# Fold: 0
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6557
# [200]	valid_0's rmse: 1.57828
# [300]	valid_0's rmse: 1.55684
# [400]	valid_0's rmse: 1.54941
# [500]	valid_0's rmse: 1.5453
# [600]	valid_0's rmse: 1.54333
# [700]	valid_0's rmse: 1.54098
# [800]	valid_0's rmse: 1.53943
# [900]	valid_0's rmse: 1.53848
# Early stopping, best iteration is:
# [921]	valid_0's rmse: 1.53835
# Fold: 1
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63155
# [200]	valid_0's rmse: 1.5574
# [300]	valid_0's rmse: 1.53903
# [400]	valid_0's rmse: 1.53289
# [500]	valid_0's rmse: 1.52944
# [600]	valid_0's rmse: 1.52778
# [700]	valid_0's rmse: 1.52705
# [800]	valid_0's rmse: 1.52633
# [900]	valid_0's rmse: 1.52523
# [1000]	valid_0's rmse: 1.5243
# [1100]	valid_0's rmse: 1.52337
# [1200]	valid_0's rmse: 1.52315
# [1300]	valid_0's rmse: 1.52281
# Early stopping, best iteration is:
# [1346]	valid_0's rmse: 1.52255
# Fold: 2
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6412
# [200]	valid_0's rmse: 1.55969
# [300]	valid_0's rmse: 1.53615
# [400]	valid_0's rmse: 1.52761
# [500]	valid_0's rmse: 1.52332
# [600]	valid_0's rmse: 1.52175
# [700]	valid_0's rmse: 1.52045
# [800]	valid_0's rmse: 1.51886
# [900]	valid_0's rmse: 1.51792
# [1000]	valid_0's rmse: 1.51751
# Early stopping, best iteration is:
# [972]	valid_0's rmse: 1.51728
# Fold: 3
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.62783
# [200]	valid_0's rmse: 1.55027
# [300]	valid_0's rmse: 1.5302
# [400]	valid_0's rmse: 1.52276
# [500]	valid_0's rmse: 1.52003
# [600]	valid_0's rmse: 1.51919
# [700]	valid_0's rmse: 1.51829
# [800]	valid_0's rmse: 1.51708
# [900]	valid_0's rmse: 1.51667
# [1000]	valid_0's rmse: 1.51635
# Early stopping, best iteration is:
# [962]	valid_0's rmse: 1.51628
# Fold: 4
# Fitting model...
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.65795
# [200]	valid_0's rmse: 1.58374
# [300]	valid_0's rmse: 1.56546
# [400]	valid_0's rmse: 1.55853
# [500]	valid_0's rmse: 1.55471
# [600]	valid_0's rmse: 1.55378
# [700]	valid_0's rmse: 1.55344
# [800]	valid_0's rmse: 1.5524
# [900]	valid_0's rmse: 1.55207
# [1000]	valid_0's rmse: 1.55169
# Early stopping, best iteration is:
# [989]	valid_0's rmse: 1.55158
# 18.6920437666202

# %%
gs = {
    '10000est_25md_54nl': [1.53524, 1.52283, 1.51882, 1.51569, 1.55264],
    '10000est_25md_25nl': [1.53939, 1.52524, 1.52115, 1.51599, 1.55375],
    '10000est_25md_75nl': [1.53835, 1.52255, 1.51728, 1.51628, 1.55158],
}

# %%
for k, v in gs.items(): print('{}:'.format(k), np.array(v).mean())
# Out:
# 10000est_25md_54nl: 1.529044
# 10000est_25md_25nl: 1.531104
# 10000est_25md_75nl: 1.529208
